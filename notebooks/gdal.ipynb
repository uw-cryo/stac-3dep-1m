# %% [markdown]
# # GDAL

# %% [markdown]
# ## CLI

# %%
# %%bash
#
# gdal vector info ../catalogv2.parquet --of text
# Out:
# INFO: Open of `../catalogv2.parquet'
#       using driver `Parquet' successful.
#
# Layer name: catalogv2
# Geometry: Polygon
# Feature Count: 108848
# Extent: (-158.324579, 17.626785) - (-64.508840, 49.458790)
# Layer SRS WKT:
# GEOGCRS["WGS 84",
#     ENSEMBLE["World Geodetic System 1984 ensemble",
#         MEMBER["World Geodetic System 1984 (Transit)"],
#         MEMBER["World Geodetic System 1984 (G730)"],
#         MEMBER["World Geodetic System 1984 (G873)"],
#         MEMBER["World Geodetic System 1984 (G1150)"],
#         MEMBER["World Geodetic System 1984 (G1674)"],
#         MEMBER["World Geodetic System 1984 (G1762)"],
#         MEMBER["World Geodetic System 1984 (G2139)"],
#         MEMBER["World Geodetic System 1984 (G2296)"],
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]],
#         ENSEMBLEACCURACY[2.0]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433]],
#     CS[ellipsoidal,2],
# ...

# %%
# %%bash
#
# gdal vector info /vsicurl/https://github.com/uw-cryo/stac-3dep-1m/releases/download/v0.2/catalogv2.parquet --of text
# Out:
# INFO: Open of `/vsicurl/https://github.com/uw-cryo/stac-3dep-1m/releases/download/v0.2/catalogv2.parquet'
#       using driver `Parquet' successful.
#
# Layer name: catalogv2
# Geometry: Polygon
# Feature Count: 108848
# Extent: (-158.324579, 17.626785) - (-64.508840, 49.458790)
# Layer SRS WKT:
# GEOGCRS["WGS 84",
#     ENSEMBLE["World Geodetic System 1984 ensemble",
#         MEMBER["World Geodetic System 1984 (Transit)"],
#         MEMBER["World Geodetic System 1984 (G730)"],
#         MEMBER["World Geodetic System 1984 (G873)"],
#         MEMBER["World Geodetic System 1984 (G1150)"],
#         MEMBER["World Geodetic System 1984 (G1674)"],
#         MEMBER["World Geodetic System 1984 (G1762)"],
#         MEMBER["World Geodetic System 1984 (G2139)"],
#         MEMBER["World Geodetic System 1984 (G2296)"],
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]],
#         ENSEMBLEACCURACY[2.0]],
#     PRIMEM["Greenwich",0,
# ...

# %%
# NOTE: does not wor with relative path:
#!gdal raster info ../catalog.gti --of text

# gdal raster info /vsicurl/https://github.com/uw-cryo/stac-3dep-1m/releases/download/v0.2/catalog.gti --of text

# %%
# %%bash
#
# # Works in same directory
# cd ../
# gdal raster info catalog.gti --of text
# Out:
# Driver: GTI/GDAL Raster Tile Index
# Files: catalog.gti
# Size is 10423971, 3536890
# Coordinate System is:
# GEOGCRS["WGS 84",
#     ENSEMBLE["World Geodetic System 1984 ensemble",
#         MEMBER["World Geodetic System 1984 (Transit)"],
#         MEMBER["World Geodetic System 1984 (G730)"],
#         MEMBER["World Geodetic System 1984 (G873)"],
#         MEMBER["World Geodetic System 1984 (G1150)"],
#         MEMBER["World Geodetic System 1984 (G1674)"],
#         MEMBER["World Geodetic System 1984 (G1762)"],
#         MEMBER["World Geodetic System 1984 (G2139)"],
#         MEMBER["World Geodetic System 1984 (G2296)"],
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]],
#         ENSEMBLEACCURACY[2.0]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433]],
#     CS[ellipsoidal,2],
#         AXIS["geodetic latitude (Lat)",north,
#             ORDER[1],
#             ANGLEUNIT["degree",0.0174532925199433]],
# ...
